# %% [markdown]
# <a href="https://colab.research.google.com/github/toufiqmusah/CALADAN/blob/main/Ocular_Disease_Classification(ResNet)_CALADAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #DATA PREPARATION

# %% [markdown]
# IMPORTING LIBRARIES

# %%
import shutil
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install -q torchinfo
from torchinfo import summary

# %%
import os
import torch
from torch import nn
from torch.utils.data import DataLoader, random_split

import torchvision
from torchvision.utils import make_grid
from torchvision import datasets, transforms

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device, torch.__version__, os.cpu_count()
# Out:
# (device(type='cuda'), '2.2.1+cu121', 2)

# %% [markdown]
# GETTING DATA

# %%
# !gdown -qq 1F_k5qvgvPldUEPNlunM49inPnI8Ti8GY
# !unzip -qq '/content/OCULAR-DISEASE-DATASET.zip'

# %%
data_df = pd.read_csv('/content/full_df.csv')

# %%
path = '/content/ODIR-5K/ODIR-5K'
img_name = data_df['filename'].iloc[0]
file = path + "Training Images/" + img_name

training_path = path + "Training Images/"

# %%
print(f"Train : {len(os.listdir('/content/ODIR-5K/ODIR-5K/Training Images'))}, Test : {len(os.listdir('/content/ODIR-5K/ODIR-5K/Testing Images'))}, Prepocess : {len(os.listdir('/content/preprocessed_images'))}")
# Out:
# Train : 7000, Test : 1000, Prepocess : 6392

# %%
data_df['labels'].unique()
# Out:
# array(["['N']", "['D']", "['O']", "['M']", "['H']", "['C']", "['A']",
#        "['G']"], dtype=object)

# %% [markdown]
# Creating Dataset Folders

# %%
# !mkdir ODIR-Dataset

# %%
label_map = { "['N']" : 'Normal', "['D']" : 'Diabetic Ret',
             "['G']" : 'Glaucoma', "['O']" : 'Other Disease',
             "['H']" : 'Hypertension', "['M']" : 'Myopia',
             "['A']" : 'AMD', "['C']" : 'Cataract'}

data_df['labels'] = data_df['labels'].map(label_map)

source_dir = '/content/preprocessed_images'
destination_dir = '/content/ODIR-Dataset'

def ensure_dir(directory):
    if not os.path.exists(directory):
        os.makedirs(directory)

for index, row in data_df.iterrows():
    source_file = os.path.join(source_dir, row['filename'])
    label_dir = os.path.join(destination_dir, row['labels'])
    ensure_dir(label_dir)

    destination_file = os.path.join(label_dir, row['filename'])
    shutil.move(source_file, destination_file)

print("Files have been organized into label-based directories.")
# Out:
# Files have been organized into label-based directories.

# %%
data_path = '/content/ODIR-Dataset'

# %%
# !rm -rf '/content/ODIR-Dataset/Other Disease'
# !rm -rf '/content/ODIR-Dataset/Myopia'
# !rm -rf '/content/ODIR-Dataset/Hypertension'
# !rm -rf '/content/ODIR-Dataset/AMD'
# !rm -rf '/content/ODIR-Dataset/Glaucoma'

# %% [markdown]
# Visualising Class Image Grids

# %%
data_transforms = transforms.Compose([transforms.Resize(size = (128, 128)),
                                      transforms.TrivialAugmentWide(num_magnitude_bins = 5),
                                      transforms.ToTensor()])

all_data = datasets.ImageFolder(root = data_path, transform = data_transforms)

all_data_loader = DataLoader(all_data, batch_size = 64, shuffle = True)

# %% [markdown]
# Visualizing Some Data

# %%
images, labels = next(iter(all_data_loader))
grid = make_grid(images[:32], normalize = True)
plt.imshow(grid.permute(1, 2, 0))
plt.axis('off')
# Out:
# (-0.5, 1041.5, 521.5, -0.5)

# %% [markdown]
# Creating DataLoaders

# %%
images[0].shape
# Out:
# torch.Size([3, 128, 128])

# %%
batch_size = 64

train_data, test_data, valid_data = random_split(all_data, [0.7, 0.2, 0.1])

train_dataloader = DataLoader(train_data, batch_size = batch_size)
test_dataloader = DataLoader(test_data, batch_size = batch_size)
valid_dataloader = DataLoader(valid_data, batch_size = batch_size)

classes = all_data.classes

len(classes), train_dataloader, test_dataloader, valid_dataloader
# Out:
# (3,
#  <torch.utils.data.dataloader.DataLoader at 0x79a981396290>,
#  <torch.utils.data.dataloader.DataLoader at 0x79aa8c514eb0>,
#  <torch.utils.data.dataloader.DataLoader at 0x79a981395e70>)

# %% [markdown]
# #MODEL IMPLEMENTATION

# %%
# !git clone -qq https://github.com/toufiqmusah/CALADAN.git

# %%
from CALADAN.modular_torch import engine, data_setup

# %% [markdown]
# Creating Model-Specific DataLoaders

# %%
weights = torchvision.models.ResNet101_Weights.DEFAULT
weights
# Out:
# ResNet101_Weights.IMAGENET1K_V2

# %%
auto_transforms = weights.transforms()
auto_transforms

custom_transforms = [transforms.TrivialAugmentWide(num_magnitude_bins = 8)]

all_transforms = transforms.Compose([
    *custom_transforms,
    auto_transforms
])

all_transforms
# Out:
# Compose(
#     TrivialAugmentWide(num_magnitude_bins=8, interpolation=InterpolationMode.NEAREST, fill=None)
#     ImageClassification(
#     crop_size=[224]
#     resize_size=[232]
#     mean=[0.485, 0.456, 0.406]
#     std=[0.229, 0.224, 0.225]
#     interpolation=InterpolationMode.BILINEAR
# )
# )

# %%
all_data = datasets.ImageFolder(root = data_path, transform = all_transforms)

all_data_loader = DataLoader(all_data, batch_size = 64, shuffle = True)

# %%
batch_size = 64

train_data, test_data, valid_data = random_split(all_data, [0.7, 0.2, 0.1])

train_dataloader = DataLoader(train_data, batch_size = batch_size)
test_dataloader = DataLoader(test_data, batch_size = batch_size)
valid_dataloader = DataLoader(valid_data, batch_size = batch_size)

classes = all_data.classes

len(classes), train_dataloader, test_dataloader, valid_dataloader
# Out:
# (3,
#  <torch.utils.data.dataloader.DataLoader at 0x79a981454c10>,
#  <torch.utils.data.dataloader.DataLoader at 0x79a981455f00>,
#  <torch.utils.data.dataloader.DataLoader at 0x79a9814572e0>)

# %%
images_1, labels_1 = next(iter(all_data_loader))
grid = make_grid(images[:32], normalize = True)
plt.imshow(grid.permute(1, 2, 0))
plt.axis('off')
# Out:
# (-0.5, 1041.5, 521.5, -0.5)

# %% [markdown]
# Setting Up a Pre-Trained Model

# %%
model = torchvision.models.resnet101(weights = weights).to(device)

summary(model = model,
        input_size = (64, 3, 255, 255),
        col_names = ['input_size', 'output_size', 'num_params', 'trainable'],
        col_width = 24,
        row_settings = ['var_names']
)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet101-cd907fc2.pth" to /root/.cache/torch/hub/checkpoints/resnet101-cd907fc2.pth
# 100%|██████████| 171M/171M [00:01<00:00, 151MB/s]
# ========================================================================================================================================
# Layer (type (var_name))                  Input Shape              Output Shape             Param #                  Trainable
# ========================================================================================================================================
# ResNet (ResNet)                          [64, 3, 255, 255]        [64, 1000]               --                       True
# ├─Conv2d (conv1)                         [64, 3, 255, 255]        [64, 64, 128, 128]       9,408                    True
# ├─BatchNorm2d (bn1)                      [64, 64, 128, 128]       [64, 64, 128, 128]       128                      True
# ├─ReLU (relu)                            [64, 64, 128, 128]       [64, 64, 128, 128]       --                       --
# ├─MaxPool2d (maxpool)                    [64, 64, 128, 128]       [64, 64, 64, 64]         --                       --
# ├─Sequential (layer1)                    [64, 64, 64, 64]         [64, 256, 64, 64]        --                       True
# │    └─Bottleneck (0)                    [64, 64, 64, 64]         [64, 256, 64, 64]        --                       True
# │    │    └─Conv2d (conv1)               [64, 64, 64, 64]         [64, 64, 64, 64]         4,096                    True
# │    │    └─BatchNorm2d (bn1)            [64, 64, 64, 64]         [64, 64, 64, 64]         128                      True
# │    │    └─ReLU (relu)                  [64, 64, 64, 64]         [64, 64, 64, 64]         --                       --
# │    │    └─Conv2d (conv2)               [64, 64, 64, 64]         [64, 64, 64, 64]         36,864                   True
# │    │    └─BatchNorm2d (bn2)            [64, 64, 64, 64]         [64, 64, 64, 64]         128                      True
# │    │    └─ReLU (relu)                  [64, 64, 64, 64]         [64, 64, 64, 64]         --                       --
# │    │    └─Conv2d (conv3)               [64, 64, 64, 64]         [64, 256, 64, 64]        16,384                   True
# │    │    └─BatchNorm2d (bn3)            [64, 256, 64, 64]        [64, 256, 64, 64]        512                      True
# │    │    └─Sequential (downsample)      [64, 64, 64, 64]         [64, 256, 64, 64]        16,896                   True
# │    │    └─ReLU (relu)                  [64, 256, 64, 64]        [64, 256, 64, 64]        --                       --
# │    └─Bottleneck (1)                    [64, 256, 64, 64]        [64, 256, 64, 64]        --                       True
# │    │    └─Conv2d (conv1)               [64, 256, 64, 64]        [64, 64, 64, 64]         16,384                   True
# │    │    └─BatchNorm2d (bn1)            [64, 64, 64, 64]         [64, 64, 64, 64]         128                      True
# │    │    └─ReLU (relu)                  [64, 64, 64, 64]         [64, 64, 64, 64]         --                       --
# │    │    └─Conv2d (conv2)               [64, 64, 64, 64]         [64, 64, 64, 64]         36,864                   True
# │    │    └─BatchNorm2d (bn2)            [64, 64, 64, 64]         [64, 64, 64, 64]         128                      True
# │    │    └─ReLU (relu)                  [64, 64, 64, 64]         [64, 64, 64, 64]         --                       --
# │    │    └─Conv2d (conv3)               [64, 64, 64, 64]         [64, 256, 64, 64]        16,384                   True
# │    │    └─BatchNorm2d (bn3)            [64, 256, 64, 64]        [64, 256, 64, 64]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 64, 64]        [64, 256, 64, 64]        --                       --
# │    └─Bottleneck (2)                    [64, 256, 64, 64]        [64, 256, 64, 64]        --                       True
# │    │    └─Conv2d (conv1)               [64, 256, 64, 64]        [64, 64, 64, 64]         16,384                   True
# │    │    └─BatchNorm2d (bn1)            [64, 64, 64, 64]         [64, 64, 64, 64]         128                      True
# │    │    └─ReLU (relu)                  [64, 64, 64, 64]         [64, 64, 64, 64]         --                       --
# │    │    └─Conv2d (conv2)               [64, 64, 64, 64]         [64, 64, 64, 64]         36,864                   True
# │    │    └─BatchNorm2d (bn2)            [64, 64, 64, 64]         [64, 64, 64, 64]         128                      True
# │    │    └─ReLU (relu)                  [64, 64, 64, 64]         [64, 64, 64, 64]         --                       --
# │    │    └─Conv2d (conv3)               [64, 64, 64, 64]         [64, 256, 64, 64]        16,384                   True
# │    │    └─BatchNorm2d (bn3)            [64, 256, 64, 64]        [64, 256, 64, 64]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 64, 64]        [64, 256, 64, 64]        --                       --
# ├─Sequential (layer2)                    [64, 256, 64, 64]        [64, 512, 32, 32]        --                       True
# │    └─Bottleneck (0)                    [64, 256, 64, 64]        [64, 512, 32, 32]        --                       True
# │    │    └─Conv2d (conv1)               [64, 256, 64, 64]        [64, 128, 64, 64]        32,768                   True
# │    │    └─BatchNorm2d (bn1)            [64, 128, 64, 64]        [64, 128, 64, 64]        256                      True
# │    │    └─ReLU (relu)                  [64, 128, 64, 64]        [64, 128, 64, 64]        --                       --
# │    │    └─Conv2d (conv2)               [64, 128, 64, 64]        [64, 128, 32, 32]        147,456                  True
# │    │    └─BatchNorm2d (bn2)            [64, 128, 32, 32]        [64, 128, 32, 32]        256                      True
# │    │    └─ReLU (relu)                  [64, 128, 32, 32]        [64, 128, 32, 32]        --                       --
# │    │    └─Conv2d (conv3)               [64, 128, 32, 32]        [64, 512, 32, 32]        65,536                   True
# │    │    └─BatchNorm2d (bn3)            [64, 512, 32, 32]        [64, 512, 32, 32]        1,024                    True
# │    │    └─Sequential (downsample)      [64, 256, 64, 64]        [64, 512, 32, 32]        132,096                  True
# │    │    └─ReLU (relu)                  [64, 512, 32, 32]        [64, 512, 32, 32]        --                       --
# │    └─Bottleneck (1)                    [64, 512, 32, 32]        [64, 512, 32, 32]        --                       True
# │    │    └─Conv2d (conv1)               [64, 512, 32, 32]        [64, 128, 32, 32]        65,536                   True
# │    │    └─BatchNorm2d (bn1)            [64, 128, 32, 32]        [64, 128, 32, 32]        256                      True
# │    │    └─ReLU (relu)                  [64, 128, 32, 32]        [64, 128, 32, 32]        --                       --
# │    │    └─Conv2d (conv2)               [64, 128, 32, 32]        [64, 128, 32, 32]        147,456                  True
# │    │    └─BatchNorm2d (bn2)            [64, 128, 32, 32]        [64, 128, 32, 32]        256                      True
# │    │    └─ReLU (relu)                  [64, 128, 32, 32]        [64, 128, 32, 32]        --                       --
# │    │    └─Conv2d (conv3)               [64, 128, 32, 32]        [64, 512, 32, 32]        65,536                   True
# │    │    └─BatchNorm2d (bn3)            [64, 512, 32, 32]        [64, 512, 32, 32]        1,024                    True
# │    │    └─ReLU (relu)                  [64, 512, 32, 32]        [64, 512, 32, 32]        --                       --
# │    └─Bottleneck (2)                    [64, 512, 32, 32]        [64, 512, 32, 32]        --                       True
# │    │    └─Conv2d (conv1)               [64, 512, 32, 32]        [64, 128, 32, 32]        65,536                   True
# │    │    └─BatchNorm2d (bn1)            [64, 128, 32, 32]        [64, 128, 32, 32]        256                      True
# │    │    └─ReLU (relu)                  [64, 128, 32, 32]        [64, 128, 32, 32]        --                       --
# │    │    └─Conv2d (conv2)               [64, 128, 32, 32]        [64, 128, 32, 32]        147,456                  True
# │    │    └─BatchNorm2d (bn2)            [64, 128, 32, 32]        [64, 128, 32, 32]        256                      True
# │    │    └─ReLU (relu)                  [64, 128, 32, 32]        [64, 128, 32, 32]        --                       --
# │    │    └─Conv2d (conv3)               [64, 128, 32, 32]        [64, 512, 32, 32]        65,536                   True
# │    │    └─BatchNorm2d (bn3)            [64, 512, 32, 32]        [64, 512, 32, 32]        1,024                    True
# │    │    └─ReLU (relu)                  [64, 512, 32, 32]        [64, 512, 32, 32]        --                       --
# │    └─Bottleneck (3)                    [64, 512, 32, 32]        [64, 512, 32, 32]        --                       True
# │    │    └─Conv2d (conv1)               [64, 512, 32, 32]        [64, 128, 32, 32]        65,536                   True
# │    │    └─BatchNorm2d (bn1)            [64, 128, 32, 32]        [64, 128, 32, 32]        256                      True
# │    │    └─ReLU (relu)                  [64, 128, 32, 32]        [64, 128, 32, 32]        --                       --
# │    │    └─Conv2d (conv2)               [64, 128, 32, 32]        [64, 128, 32, 32]        147,456                  True
# │    │    └─BatchNorm2d (bn2)            [64, 128, 32, 32]        [64, 128, 32, 32]        256                      True
# │    │    └─ReLU (relu)                  [64, 128, 32, 32]        [64, 128, 32, 32]        --                       --
# │    │    └─Conv2d (conv3)               [64, 128, 32, 32]        [64, 512, 32, 32]        65,536                   True
# │    │    └─BatchNorm2d (bn3)            [64, 512, 32, 32]        [64, 512, 32, 32]        1,024                    True
# │    │    └─ReLU (relu)                  [64, 512, 32, 32]        [64, 512, 32, 32]        --                       --
# ├─Sequential (layer3)                    [64, 512, 32, 32]        [64, 1024, 16, 16]       --                       True
# │    └─Bottleneck (0)                    [64, 512, 32, 32]        [64, 1024, 16, 16]       --                       True
# │    │    └─Conv2d (conv1)               [64, 512, 32, 32]        [64, 256, 32, 32]        131,072                  True
# │    │    └─BatchNorm2d (bn1)            [64, 256, 32, 32]        [64, 256, 32, 32]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 32, 32]        [64, 256, 32, 32]        --                       --
# │    │    └─Conv2d (conv2)               [64, 256, 32, 32]        [64, 256, 16, 16]        589,824                  True
# │    │    └─BatchNorm2d (bn2)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv3)               [64, 256, 16, 16]        [64, 1024, 16, 16]       262,144                  True
# │    │    └─BatchNorm2d (bn3)            [64, 1024, 16, 16]       [64, 1024, 16, 16]       2,048                    True
# │    │    └─Sequential (downsample)      [64, 512, 32, 32]        [64, 1024, 16, 16]       526,336                  True
# │    │    └─ReLU (relu)                  [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       --
# │    └─Bottleneck (1)                    [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       True
# │    │    └─Conv2d (conv1)               [64, 1024, 16, 16]       [64, 256, 16, 16]        262,144                  True
# │    │    └─BatchNorm2d (bn1)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv2)               [64, 256, 16, 16]        [64, 256, 16, 16]        589,824                  True
# │    │    └─BatchNorm2d (bn2)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv3)               [64, 256, 16, 16]        [64, 1024, 16, 16]       262,144                  True
# │    │    └─BatchNorm2d (bn3)            [64, 1024, 16, 16]       [64, 1024, 16, 16]       2,048                    True
# │    │    └─ReLU (relu)                  [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       --
# │    └─Bottleneck (2)                    [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       True
# │    │    └─Conv2d (conv1)               [64, 1024, 16, 16]       [64, 256, 16, 16]        262,144                  True
# │    │    └─BatchNorm2d (bn1)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv2)               [64, 256, 16, 16]        [64, 256, 16, 16]        589,824                  True
# │    │    └─BatchNorm2d (bn2)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv3)               [64, 256, 16, 16]        [64, 1024, 16, 16]       262,144                  True
# │    │    └─BatchNorm2d (bn3)            [64, 1024, 16, 16]       [64, 1024, 16, 16]       2,048                    True
# │    │    └─ReLU (relu)                  [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       --
# │    └─Bottleneck (3)                    [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       True
# │    │    └─Conv2d (conv1)               [64, 1024, 16, 16]       [64, 256, 16, 16]        262,144                  True
# │    │    └─BatchNorm2d (bn1)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv2)               [64, 256, 16, 16]        [64, 256, 16, 16]        589,824                  True
# │    │    └─BatchNorm2d (bn2)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv3)               [64, 256, 16, 16]        [64, 1024, 16, 16]       262,144                  True
# │    │    └─BatchNorm2d (bn3)            [64, 1024, 16, 16]       [64, 1024, 16, 16]       2,048                    True
# │    │    └─ReLU (relu)                  [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       --
# │    └─Bottleneck (4)                    [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       True
# │    │    └─Conv2d (conv1)               [64, 1024, 16, 16]       [64, 256, 16, 16]        262,144                  True
# │    │    └─BatchNorm2d (bn1)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv2)               [64, 256, 16, 16]        [64, 256, 16, 16]        589,824                  True
# │    │    └─BatchNorm2d (bn2)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv3)               [64, 256, 16, 16]        [64, 1024, 16, 16]       262,144                  True
# │    │    └─BatchNorm2d (bn3)            [64, 1024, 16, 16]       [64, 1024, 16, 16]       2,048                    True
# │    │    └─ReLU (relu)                  [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       --
# │    └─Bottleneck (5)                    [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       True
# │    │    └─Conv2d (conv1)               [64, 1024, 16, 16]       [64, 256, 16, 16]        262,144                  True
# │    │    └─BatchNorm2d (bn1)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv2)               [64, 256, 16, 16]        [64, 256, 16, 16]        589,824                  True
# │    │    └─BatchNorm2d (bn2)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv3)               [64, 256, 16, 16]        [64, 1024, 16, 16]       262,144                  True
# │    │    └─BatchNorm2d (bn3)            [64, 1024, 16, 16]       [64, 1024, 16, 16]       2,048                    True
# │    │    └─ReLU (relu)                  [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       --
# │    └─Bottleneck (6)                    [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       True
# │    │    └─Conv2d (conv1)               [64, 1024, 16, 16]       [64, 256, 16, 16]        262,144                  True
# │    │    └─BatchNorm2d (bn1)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv2)               [64, 256, 16, 16]        [64, 256, 16, 16]        589,824                  True
# │    │    └─BatchNorm2d (bn2)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv3)               [64, 256, 16, 16]        [64, 1024, 16, 16]       262,144                  True
# │    │    └─BatchNorm2d (bn3)            [64, 1024, 16, 16]       [64, 1024, 16, 16]       2,048                    True
# │    │    └─ReLU (relu)                  [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       --
# │    └─Bottleneck (7)                    [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       True
# │    │    └─Conv2d (conv1)               [64, 1024, 16, 16]       [64, 256, 16, 16]        262,144                  True
# │    │    └─BatchNorm2d (bn1)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv2)               [64, 256, 16, 16]        [64, 256, 16, 16]        589,824                  True
# │    │    └─BatchNorm2d (bn2)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv3)               [64, 256, 16, 16]        [64, 1024, 16, 16]       262,144                  True
# │    │    └─BatchNorm2d (bn3)            [64, 1024, 16, 16]       [64, 1024, 16, 16]       2,048                    True
# │    │    └─ReLU (relu)                  [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       --
# │    └─Bottleneck (8)                    [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       True
# │    │    └─Conv2d (conv1)               [64, 1024, 16, 16]       [64, 256, 16, 16]        262,144                  True
# │    │    └─BatchNorm2d (bn1)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv2)               [64, 256, 16, 16]        [64, 256, 16, 16]        589,824                  True
# │    │    └─BatchNorm2d (bn2)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv3)               [64, 256, 16, 16]        [64, 1024, 16, 16]       262,144                  True
# │    │    └─BatchNorm2d (bn3)            [64, 1024, 16, 16]       [64, 1024, 16, 16]       2,048                    True
# │    │    └─ReLU (relu)                  [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       --
# │    └─Bottleneck (9)                    [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       True
# │    │    └─Conv2d (conv1)               [64, 1024, 16, 16]       [64, 256, 16, 16]        262,144                  True
# │    │    └─BatchNorm2d (bn1)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv2)               [64, 256, 16, 16]        [64, 256, 16, 16]        589,824                  True
# │    │    └─BatchNorm2d (bn2)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv3)               [64, 256, 16, 16]        [64, 1024, 16, 16]       262,144                  True
# │    │    └─BatchNorm2d (bn3)            [64, 1024, 16, 16]       [64, 1024, 16, 16]       2,048                    True
# │    │    └─ReLU (relu)                  [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       --
# │    └─Bottleneck (10)                   [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       True
# │    │    └─Conv2d (conv1)               [64, 1024, 16, 16]       [64, 256, 16, 16]        262,144                  True
# │    │    └─BatchNorm2d (bn1)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv2)               [64, 256, 16, 16]        [64, 256, 16, 16]        589,824                  True
# │    │    └─BatchNorm2d (bn2)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv3)               [64, 256, 16, 16]        [64, 1024, 16, 16]       262,144                  True
# │    │    └─BatchNorm2d (bn3)            [64, 1024, 16, 16]       [64, 1024, 16, 16]       2,048                    True
# │    │    └─ReLU (relu)                  [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       --
# │    └─Bottleneck (11)                   [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       True
# │    │    └─Conv2d (conv1)               [64, 1024, 16, 16]       [64, 256, 16, 16]        262,144                  True
# │    │    └─BatchNorm2d (bn1)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv2)               [64, 256, 16, 16]        [64, 256, 16, 16]        589,824                  True
# │    │    └─BatchNorm2d (bn2)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv3)               [64, 256, 16, 16]        [64, 1024, 16, 16]       262,144                  True
# │    │    └─BatchNorm2d (bn3)            [64, 1024, 16, 16]       [64, 1024, 16, 16]       2,048                    True
# │    │    └─ReLU (relu)                  [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       --
# │    └─Bottleneck (12)                   [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       True
# │    │    └─Conv2d (conv1)               [64, 1024, 16, 16]       [64, 256, 16, 16]        262,144                  True
# │    │    └─BatchNorm2d (bn1)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv2)               [64, 256, 16, 16]        [64, 256, 16, 16]        589,824                  True
# │    │    └─BatchNorm2d (bn2)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv3)               [64, 256, 16, 16]        [64, 1024, 16, 16]       262,144                  True
# │    │    └─BatchNorm2d (bn3)            [64, 1024, 16, 16]       [64, 1024, 16, 16]       2,048                    True
# │    │    └─ReLU (relu)                  [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       --
# │    └─Bottleneck (13)                   [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       True
# │    │    └─Conv2d (conv1)               [64, 1024, 16, 16]       [64, 256, 16, 16]        262,144                  True
# │    │    └─BatchNorm2d (bn1)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv2)               [64, 256, 16, 16]        [64, 256, 16, 16]        589,824                  True
# │    │    └─BatchNorm2d (bn2)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv3)               [64, 256, 16, 16]        [64, 1024, 16, 16]       262,144                  True
# │    │    └─BatchNorm2d (bn3)            [64, 1024, 16, 16]       [64, 1024, 16, 16]       2,048                    True
# │    │    └─ReLU (relu)                  [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       --
# │    └─Bottleneck (14)                   [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       True
# │    │    └─Conv2d (conv1)               [64, 1024, 16, 16]       [64, 256, 16, 16]        262,144                  True
# │    │    └─BatchNorm2d (bn1)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv2)               [64, 256, 16, 16]        [64, 256, 16, 16]        589,824                  True
# │    │    └─BatchNorm2d (bn2)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv3)               [64, 256, 16, 16]        [64, 1024, 16, 16]       262,144                  True
# │    │    └─BatchNorm2d (bn3)            [64, 1024, 16, 16]       [64, 1024, 16, 16]       2,048                    True
# │    │    └─ReLU (relu)                  [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       --
# │    └─Bottleneck (15)                   [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       True
# │    │    └─Conv2d (conv1)               [64, 1024, 16, 16]       [64, 256, 16, 16]        262,144                  True
# │    │    └─BatchNorm2d (bn1)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv2)               [64, 256, 16, 16]        [64, 256, 16, 16]        589,824                  True
# │    │    └─BatchNorm2d (bn2)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv3)               [64, 256, 16, 16]        [64, 1024, 16, 16]       262,144                  True
# │    │    └─BatchNorm2d (bn3)            [64, 1024, 16, 16]       [64, 1024, 16, 16]       2,048                    True
# │    │    └─ReLU (relu)                  [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       --
# │    └─Bottleneck (16)                   [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       True
# │    │    └─Conv2d (conv1)               [64, 1024, 16, 16]       [64, 256, 16, 16]        262,144                  True
# │    │    └─BatchNorm2d (bn1)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv2)               [64, 256, 16, 16]        [64, 256, 16, 16]        589,824                  True
# │    │    └─BatchNorm2d (bn2)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv3)               [64, 256, 16, 16]        [64, 1024, 16, 16]       262,144                  True
# │    │    └─BatchNorm2d (bn3)            [64, 1024, 16, 16]       [64, 1024, 16, 16]       2,048                    True
# │    │    └─ReLU (relu)                  [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       --
# │    └─Bottleneck (17)                   [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       True
# │    │    └─Conv2d (conv1)               [64, 1024, 16, 16]       [64, 256, 16, 16]        262,144                  True
# │    │    └─BatchNorm2d (bn1)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv2)               [64, 256, 16, 16]        [64, 256, 16, 16]        589,824                  True
# │    │    └─BatchNorm2d (bn2)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv3)               [64, 256, 16, 16]        [64, 1024, 16, 16]       262,144                  True
# │    │    └─BatchNorm2d (bn3)            [64, 1024, 16, 16]       [64, 1024, 16, 16]       2,048                    True
# │    │    └─ReLU (relu)                  [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       --
# │    └─Bottleneck (18)                   [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       True
# │    │    └─Conv2d (conv1)               [64, 1024, 16, 16]       [64, 256, 16, 16]        262,144                  True
# │    │    └─BatchNorm2d (bn1)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv2)               [64, 256, 16, 16]        [64, 256, 16, 16]        589,824                  True
# │    │    └─BatchNorm2d (bn2)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv3)               [64, 256, 16, 16]        [64, 1024, 16, 16]       262,144                  True
# │    │    └─BatchNorm2d (bn3)            [64, 1024, 16, 16]       [64, 1024, 16, 16]       2,048                    True
# │    │    └─ReLU (relu)                  [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       --
# │    └─Bottleneck (19)                   [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       True
# │    │    └─Conv2d (conv1)               [64, 1024, 16, 16]       [64, 256, 16, 16]        262,144                  True
# │    │    └─BatchNorm2d (bn1)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv2)               [64, 256, 16, 16]        [64, 256, 16, 16]        589,824                  True
# │    │    └─BatchNorm2d (bn2)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv3)               [64, 256, 16, 16]        [64, 1024, 16, 16]       262,144                  True
# │    │    └─BatchNorm2d (bn3)            [64, 1024, 16, 16]       [64, 1024, 16, 16]       2,048                    True
# │    │    └─ReLU (relu)                  [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       --
# │    └─Bottleneck (20)                   [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       True
# │    │    └─Conv2d (conv1)               [64, 1024, 16, 16]       [64, 256, 16, 16]        262,144                  True
# │    │    └─BatchNorm2d (bn1)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv2)               [64, 256, 16, 16]        [64, 256, 16, 16]        589,824                  True
# │    │    └─BatchNorm2d (bn2)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv3)               [64, 256, 16, 16]        [64, 1024, 16, 16]       262,144                  True
# │    │    └─BatchNorm2d (bn3)            [64, 1024, 16, 16]       [64, 1024, 16, 16]       2,048                    True
# │    │    └─ReLU (relu)                  [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       --
# │    └─Bottleneck (21)                   [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       True
# │    │    └─Conv2d (conv1)               [64, 1024, 16, 16]       [64, 256, 16, 16]        262,144                  True
# │    │    └─BatchNorm2d (bn1)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv2)               [64, 256, 16, 16]        [64, 256, 16, 16]        589,824                  True
# │    │    └─BatchNorm2d (bn2)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv3)               [64, 256, 16, 16]        [64, 1024, 16, 16]       262,144                  True
# │    │    └─BatchNorm2d (bn3)            [64, 1024, 16, 16]       [64, 1024, 16, 16]       2,048                    True
# │    │    └─ReLU (relu)                  [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       --
# │    └─Bottleneck (22)                   [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       True
# │    │    └─Conv2d (conv1)               [64, 1024, 16, 16]       [64, 256, 16, 16]        262,144                  True
# │    │    └─BatchNorm2d (bn1)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv2)               [64, 256, 16, 16]        [64, 256, 16, 16]        589,824                  True
# │    │    └─BatchNorm2d (bn2)            [64, 256, 16, 16]        [64, 256, 16, 16]        512                      True
# │    │    └─ReLU (relu)                  [64, 256, 16, 16]        [64, 256, 16, 16]        --                       --
# │    │    └─Conv2d (conv3)               [64, 256, 16, 16]        [64, 1024, 16, 16]       262,144                  True
# │    │    └─BatchNorm2d (bn3)            [64, 1024, 16, 16]       [64, 1024, 16, 16]       2,048                    True
# │    │    └─ReLU (relu)                  [64, 1024, 16, 16]       [64, 1024, 16, 16]       --                       --
# ├─Sequential (layer4)                    [64, 1024, 16, 16]       [64, 2048, 8, 8]         --                       True
# │    └─Bottleneck (0)                    [64, 1024, 16, 16]       [64, 2048, 8, 8]         --                       True
# │    │    └─Conv2d (conv1)               [64, 1024, 16, 16]       [64, 512, 16, 16]        524,288                  True
# │    │    └─BatchNorm2d (bn1)            [64, 512, 16, 16]        [64, 512, 16, 16]        1,024                    True
# │    │    └─ReLU (relu)                  [64, 512, 16, 16]        [64, 512, 16, 16]        --                       --
# │    │    └─Conv2d (conv2)               [64, 512, 16, 16]        [64, 512, 8, 8]          2,359,296                True
# │    │    └─BatchNorm2d (bn2)            [64, 512, 8, 8]          [64, 512, 8, 8]          1,024                    True
# │    │    └─ReLU (relu)                  [64, 512, 8, 8]          [64, 512, 8, 8]          --                       --
# │    │    └─Conv2d (conv3)               [64, 512, 8, 8]          [64, 2048, 8, 8]         1,048,576                True
# │    │    └─BatchNorm2d (bn3)            [64, 2048, 8, 8]         [64, 2048, 8, 8]         4,096                    True
# │    │    └─Sequential (downsample)      [64, 1024, 16, 16]       [64, 2048, 8, 8]         2,101,248                True
# │    │    └─ReLU (relu)                  [64, 2048, 8, 8]         [64, 2048, 8, 8]         --                       --
# │    └─Bottleneck (1)                    [64, 2048, 8, 8]         [64, 2048, 8, 8]         --                       True
# │    │    └─Conv2d (conv1)               [64, 2048, 8, 8]         [64, 512, 8, 8]          1,048,576                True
# │    │    └─BatchNorm2d (bn1)            [64, 512, 8, 8]          [64, 512, 8, 8]          1,024                    True
# │    │    └─ReLU (relu)                  [64, 512, 8, 8]          [64, 512, 8, 8]          --                       --
# │    │    └─Conv2d (conv2)               [64, 512, 8, 8]          [64, 512, 8, 8]          2,359,296                True
# │    │    └─BatchNorm2d (bn2)            [64, 512, 8, 8]          [64, 512, 8, 8]          1,024                    True
# │    │    └─ReLU (relu)                  [64, 512, 8, 8]          [64, 512, 8, 8]          --                       --
# │    │    └─Conv2d (conv3)               [64, 512, 8, 8]          [64, 2048, 8, 8]         1,048,576                True
# │    │    └─BatchNorm2d (bn3)            [64, 2048, 8, 8]         [64, 2048, 8, 8]         4,096                    True
# │    │    └─ReLU (relu)                  [64, 2048, 8, 8]         [64, 2048, 8, 8]         --                       --
# │    └─Bottleneck (2)                    [64, 2048, 8, 8]         [64, 2048, 8, 8]         --                       True
# │    │    └─Conv2d (conv1)               [64, 2048, 8, 8]         [64, 512, 8, 8]          1,048,576                True
# │    │    └─BatchNorm2d (bn1)            [64, 512, 8, 8]          [64, 512, 8, 8]          1,024                    True
# │    │    └─ReLU (relu)                  [64, 512, 8, 8]          [64, 512, 8, 8]          --                       --
# │    │    └─Conv2d (conv2)               [64, 512, 8, 8]          [64, 512, 8, 8]          2,359,296                True
# │    │    └─BatchNorm2d (bn2)            [64, 512, 8, 8]          [64, 512, 8, 8]          1,024                    True
# │    │    └─ReLU (relu)                  [64, 512, 8, 8]          [64, 512, 8, 8]          --                       --
# │    │    └─Conv2d (conv3)               [64, 512, 8, 8]          [64, 2048, 8, 8]         1,048,576                True
# │    │    └─BatchNorm2d (bn3)            [64, 2048, 8, 8]         [64, 2048, 8, 8]         4,096                    True
# │    │    └─ReLU (relu)                  [64, 2048, 8, 8]         [64, 2048, 8, 8]         --                       --
# ├─AdaptiveAvgPool2d (avgpool)            [64, 2048, 8, 8]         [64, 2048, 1, 1]         --                       --
# ├─Linear (fc)                            [64, 2048]               [64, 1000]               2,049,000                True
# ========================================================================================================================================
# Total params: 44,549,160
# Trainable params: 44,549,160
# Non-trainable params: 0
# Total mult-adds (G): 652.10
# ========================================================================================================================================
# Input size (MB): 49.94
# Forward/backward pass size (MB): 21710.23
# Params size (MB): 178.20
# Estimated Total Size (MB): 21938.37
# ========================================================================================================================================

# %% [markdown]
# Freezing Base Layers

# %%
for param in model.layer1.parameters():
  param.requires_grad = False

# %% [markdown]
# Editing Final Layers of EfficientNet-B1

# %%
torch.manual_seed(42)
torch.cuda.manual_seed(42)

output_shape = len(classes)

model.classifier = torch.nn.Sequential(
    torch.nn.Dropout(p = 0.2,inplace =True),
    torch.nn.Linear(in_features = 1280,
                    out_features = output_shape,
                    bias = True).to(device)
)

# %% [markdown]
# Setting Up Model Hyper Parameters

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr = 2e-3)

model_result = engine.train(model = model,
                            train_dataloader = train_dataloader,
                            test_dataloader = test_dataloader,
                            optimizer = optimizer,
                            loss_fn = criterion,
                            epochs = 30,
                            device = device)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 0.9919 | train_acc: 0.6239 | test_loss: 0.8805 | test_acc: 0.6703
# Epoch: 2 | train_loss: 0.6419 | train_acc: 0.6861 | test_loss: 0.6922 | test_acc: 0.6770
# Epoch: 3 | train_loss: 0.6363 | train_acc: 0.7069 | test_loss: 0.6448 | test_acc: 0.6803
# Epoch: 4 | train_loss: 0.5921 | train_acc: 0.7273 | test_loss: 0.6075 | test_acc: 0.7053
# Epoch: 5 | train_loss: 0.5621 | train_acc: 0.7522 | test_loss: 0.6030 | test_acc: 0.7340
# Epoch: 6 | train_loss: 0.5536 | train_acc: 0.7498 | test_loss: 0.6461 | test_acc: 0.7179
# Epoch: 7 | train_loss: 0.5424 | train_acc: 0.7554 | test_loss: 0.5991 | test_acc: 0.7284
# Epoch: 8 | train_loss: 0.5091 | train_acc: 0.7738 | test_loss: 0.5532 | test_acc: 0.7466
# Epoch: 9 | train_loss: 0.5102 | train_acc: 0.7716 | test_loss: 0.6726 | test_acc: 0.7360
# Epoch: 10 | train_loss: 0.4965 | train_acc: 0.7743 | test_loss: 0.5573 | test_acc: 0.7661
# Epoch: 11 | train_loss: 0.4789 | train_acc: 0.7899 | test_loss: 0.5706 | test_acc: 0.7309
# Epoch: 12 | train_loss: 0.4630 | train_acc: 0.8041 | test_loss: 0.5851 | test_acc: 0.7401
# Epoch: 13 | train_loss: 0.4575 | train_acc: 0.8014 | test_loss: 0.5400 | test_acc: 0.7492
# Epoch: 14 | train_loss: 0.4327 | train_acc: 0.8144 | test_loss: 0.5494 | test_acc: 0.7462
# Epoch: 15 | train_loss: 0.4468 | train_acc: 0.8082 | test_loss: 0.6005 | test_acc: 0.7328
# Epoch: 16 | train_loss: 0.4285 | train_acc: 0.8225 | test_loss: 0.5373 | test_acc: 0.7579
# Epoch: 17 | train_loss: 0.4184 | train_acc: 0.8218 | test_loss: 0.5695 | test_acc: 0.7663
# Epoch: 18 | train_loss: 0.3906 | train_acc: 0.8414 | test_loss: 0.5586 | test_acc: 0.7455
# Epoch: 19 | train_loss: 0.3894 | train_acc: 0.8426 | test_loss: 0.5621 | test_acc: 0.7494
# Epoch: 20 | train_loss: 0.3869 | train_acc: 0.8274 | test_loss: 0.6289 | test_acc: 0.7382
# Epoch: 21 | train_loss: 0.3457 | train_acc: 0.8589 | test_loss: 0.5807 | test_acc: 0.7403
# Epoch: 22 | train_loss: 0.3615 | train_acc: 0.8462 | test_loss: 0.6170 | test_acc: 0.7419
# Epoch: 23 | train_loss: 0.3490 | train_acc: 0.8576 | test_loss: 0.6596 | test_acc: 0.7107
# Epoch: 24 | train_loss: 0.3249 | train_acc: 0.8592 | test_loss: 0.6195 | test_acc: 0.7389
# Epoch: 25 | train_loss: 0.3519 | train_acc: 0.8539 | test_loss: 0.6154 | test_acc: 0.7220
# Epoch: 26 | train_loss: 0.3143 | train_acc: 0.8667 | test_loss: 0.5658 | test_acc: 0.7451
# Epoch: 27 | train_loss: 0.3328 | train_acc: 0.8597 | test_loss: 0.6320 | test_acc: 0.7436
# Epoch: 28 | train_loss: 0.2884 | train_acc: 0.8846 | test_loss: 0.6773 | test_acc: 0.7120
# Epoch: 29 | train_loss: 0.3012 | train_acc: 0.8744 | test_loss: 0.6826 | test_acc: 0.6889
# Epoch: 30 | train_loss: 0.2951 | train_acc: 0.8785 | test_loss: 0.6731 | test_acc: 0.6952

# %%
try:
    from helper_functions import plot_loss_curves
except:
    print("[INFO] Couldn't find helper_functions.py, downloading...")
    with open("helper_functions.py", "wb") as f:
        import requests
        request = requests.get("https://raw.githubusercontent.com/mrdbourke/pytorch-deep-learning/main/helper_functions.py")
        f.write(request.content)
    from helper_functions import plot_loss_curves

# Plot the loss curves of our model
plot_loss_curves(model_result)
# Out:
# [INFO] Couldn't find helper_functions.py, downloading...

# %%
torch.save(model, '/content/CALADAN-ResNet-70%')
